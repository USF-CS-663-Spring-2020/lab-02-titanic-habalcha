# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math
df = pd.read_csv("titanic.csv", sep='\t')
dfc = df.copy()

# %%
dfc.describe() #we dont have any null or 0 Fare
dfc.Survived.value_counts() #count the number of individuals that died and those that survived
pSurvived = dfc[dfc.Survived == 1] 
pDied = dfc[dfc.Survived == 0]
survivalRate = pSurvived.shape[0]/156 #the probability of survival

# %%
fig = sns.boxplot(y = 'Fare', x = 'Survived', hue = 'Survived', data = dfc)
